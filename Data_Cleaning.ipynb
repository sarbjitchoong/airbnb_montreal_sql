# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
import string 
import re

# %%
df = pd.read_csv("listings.csv")

# %%
df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0    2843    https://www.airbnb.com/rooms/2843  20220912200208   2022-09-12
# 1   29059   https://www.airbnb.com/rooms/29059  20220912200208   2022-09-13
# 2  298059  https://www.airbnb.com/rooms/298059  20220912200208   2022-09-13
# 3   29061   https://www.airbnb.com/rooms/29061  20220912200208   2022-09-13
# 4  309367  https://www.airbnb.com/rooms/309367  20220912200208   2022-09-13
#
#         source                                name  \
# 0  city scrape      Fabulous downtown/airport room
# 1  city scrape        Lovely studio Quartier Latin
# 2  city scrape   Superb cottage Mile-End Plateau !
# 3  city scrape  Maison historique - Quartier Latin
# 4  city scrape    Charming and Clean ! 5 min Métro
#
#                                          description  \
# 0  Come stay in this trendy area of downtown Mont...
# 1  CITQ 267153<br />Lovely studio with 1 closed r...
# 2  <b>The space</b><br />Superb bright cottage de...
# 3  Lovely historic house with plenty of period ch...
# 4  Feel like home in a dynamic area, close to eve...
#
#                                neighborhood_overview  \
# 0  This area of St Henri is actually downtown Mon...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/397204dc-4123...     2319  ...
# 1  https://a0.muscache.com/pictures/736399/fa6c31...   125031  ...
# 2  https://a0.muscache.com/pictures/f53f3590-103d...  1536474  ...
# 3  https://a0.muscache.com/pictures/9e59d417-4b6a...   125031  ...
# 4  https://a0.muscache.com/pictures/3954937/65518...  1562348  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.73                   4.73                4.64
# 1                        4.78                   4.81                4.71
# 2                        5.00                   4.63                4.84
# 3                        4.79                   4.88                4.71
# 4                        4.91                   4.32                4.59
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                t                              2
# 1     NaN                f                              2
# 2     NaN                f                              1
# 3     NaN                f                              2
# 4     NaN                f                              3
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           2
# 2                                           1
# 3                                           2
# 4                                           3
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.97
# 1                                           0              2.58
# 2                                           0              0.40
# 3                                           0              0.84
# 4                                           0              0.18
#
# [5 rows x 75 columns]

# %%
# Converting object type to date time
df["last_scraped"] = pd.to_datetime(df["last_scraped"])
df["first_review"] = pd.to_datetime(df["first_review"])
df["last_review"] = pd.to_datetime(df["last_review"])
df["calendar_last_scraped"] = pd.to_datetime(df["calendar_last_scraped"])
df["host_since"] = pd.to_datetime(df["host_since"])

# %%
# Dropping unneccessary columns
df =df.drop(columns=['neighbourhood','host_thumbnail_url','picture_url','neighborhood_overview', 'host_about', 'neighbourhood_group_cleansed', 'bathrooms', 'calendar_updated', 'license'])

# %%
# Replacing object type null values with "None"
df[["description", 'host_url', "host_location","host_response_rate","host_acceptance_rate","beds", "listing_url","bedrooms","first_review","last_review", "host_neighbourhood"]] = df[["description", 'host_url', "host_location","host_response_rate","host_acceptance_rate","beds","listing_url","bedrooms","first_review","last_review","host_neighbourhood"]].fillna("None")

# %%
# Replacing int type null values with 0
df[["host_response_time", "host_response_rate","host_acceptance_rate","beds", "bedrooms","review_scores_rating","review_scores_accuracy", "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value", "reviews_per_month"]] = df[["host_response_time", "host_response_rate","host_acceptance_rate","beds", "bedrooms","review_scores_rating","review_scores_accuracy", "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value", "reviews_per_month"]].fillna(0)

# %%
# Dropping null values less than 20 in each column and removing duplicates
df = df.dropna()
df.drop_duplicates()
print("Null values in df = ", df.isnull().sum().sum())
# Out:
# Null values in df =  0

# %%
# Removing emojis and special characters
df["description"] = df["description"].str.replace('[^A-Za-z0-9]', ' ', flags=re.UNICODE, regex=True)

# %%
# Converting Price to numeric
df['price'] = df['price'].str.replace('$', '').str.replace(',','')
df['price'] = pd.to_numeric(df['price'])
# Out:
# /var/folders/4z/4fnbcwgx255_302rtjw9gg8c0000gn/T/ipykernel_22765/3623745663.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price'] = df['price'].str.replace('$', '').str.replace(',','')

# %%
df["price"]
# Out:
# 0         60.0
# 1        152.0
# 2        180.0
# 3        286.0
# 4         64.0
#          ...
# 13616     90.0
# 13617    188.0
# 13618     68.0
# 13619    136.0
# 13620     90.0
# Name: price, Length: 13599, dtype: float64

# %%
# Saving cleaned csv into a new file.
df.to_csv("cleaned_airbnb.csv")

# %%
df1 = pd.read_csv("cleaned_airbnb.csv")

# %%
df1.head()
# Out:
#    Unnamed: 0      id                          listing_url       scrape_id  \
# 0           0    2843    https://www.airbnb.com/rooms/2843  20220912200208
# 1           1   29059   https://www.airbnb.com/rooms/29059  20220912200208
# 2           2  298059  https://www.airbnb.com/rooms/298059  20220912200208
# 3           3   29061   https://www.airbnb.com/rooms/29061  20220912200208
# 4           4  309367  https://www.airbnb.com/rooms/309367  20220912200208
#
#   last_scraped       source                                name  \
# 0   2022-09-12  city scrape      Fabulous downtown/airport room
# 1   2022-09-13  city scrape        Lovely studio Quartier Latin
# 2   2022-09-13  city scrape   Superb cottage Mile-End Plateau !
# 3   2022-09-13  city scrape  Maison historique - Quartier Latin
# 4   2022-09-13  city scrape    Charming and Clean ! 5 min Métro
#
#                                          description  host_id  \
# 0  Come stay in this trendy area of downtown Mont...     2319
# 1  CITQ 267153 br   Lovely studio with 1 closed r...   125031
# 2   b The space  b  br   Superb bright cottage de...  1536474
# 3  Lovely historic house with plenty of period ch...   125031
# 4  Feel like home in a dynamic area  close to eve...  1562348
#
#                                     host_url  ... review_scores_checkin  \
# 0     https://www.airbnb.com/users/show/2319  ...                  4.61
# 1   https://www.airbnb.com/users/show/125031  ...                  4.81
# 2  https://www.airbnb.com/users/show/1536474  ...                  4.96
# 3   https://www.airbnb.com/users/show/125031  ...                  4.85
# 4  https://www.airbnb.com/users/show/1562348  ...                  4.86
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.73                   4.73                4.64
# 1                        4.78                   4.81                4.71
# 2                        5.00                   4.63                4.84
# 3                        4.79                   4.88                4.71
# 4                        4.91                   4.32                4.59
#
#   instant_bookable calculated_host_listings_count  \
# 0                t                              2
# 1                f                              2
# 2                f                              1
# 3                f                              2
# 4                f                              3
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           2
# 2                                           1
# 3                                           2
# 4                                           3
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                           0               0.97
# 1                                           0               2.58
# 2                                           0               0.40
# 3                                           0               0.84
# 4                                           0               0.18
#
# [5 rows x 67 columns]
